# %% [markdown]
# This is an example of developing a script locally with the West Nile Virus data to share on Kaggle
# Once you have a script you're ready to share, paste your code into a [new script](https://www.kaggle.com/c/predict-west-nile-virus/scripts/new).

# %%
# For working locally, you want to be in west_nile_scripts/working. 
# This command will move you to there, if you're in west_nile_scripts/src (where this file is).
# !cd ../working/ # Not necessary for scripts running on Kaggle
# Out:
# The system cannot find the path specified.

# %%
# Code is borrowed from: https://www.kaggle.com/users/213536/vasco/predict-west-nile-virus/west-nile-heatmap

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

mapdata = np.loadtxt("../input/mapdata_copyright_openstreetmap_contributors.txt")
traps = pd.read_csv('../input/train.csv')[['Date', 'Trap','Longitude', 'Latitude', 'WnvPresent']]
# spray = pd.read_csv('../input/spray.csv')[['Longitude', 'Latitude']]
test_trap = pd.read_csv('../input/test.csv')[['Longitude', 'Latitude']]
train_trap_hc = pd.read_csv('../input/train_trap_hc.csv')[['Longitude', 'Latitude']]
spray2 = pd.read_csv('../input/spray2.csv')[['Longitude', 'Latitude']]



aspect = mapdata.shape[0] * 1.0 / mapdata.shape[1]
lon_lat_box = (-88, -87.5, 41.6, 42.1)

plt.figure(figsize=(10,14))
plt.imshow(mapdata, 
           cmap=plt.get_cmap('gray'), 
           extent=lon_lat_box, 
           aspect=aspect)

# locations = traps[['Longitude', 'Latitude']].drop_duplicates().values
# plt.scatter(locations[:,0], locations[:,1], marker='x')

plt.scatter(-87.904724, 41.978611, marker='h') # O'Hare International Airport
plt.scatter(-87.7515, 41.7850, marker='d') # Midway International Airport
# locations_spray2 = spray2[['Longitude', 'Latitude']].drop_duplicates().values
# plt.scatter(locations_spray2[:,0], locations_spray2[:,1], marker='.')
locations_test = test_trap[['Longitude', 'Latitude']].drop_duplicates().values
plt.scatter(locations_test[:,0], locations_test[:,1], marker='1')
# train_trap_hc_test = train_trap_hc[['Longitude', 'Latitude']].drop_duplicates().values
# plt.scatter(train_trap_hc_test[:,0], train_trap_hc_test[:,1], marker='2')

# Add this when copying to a script on Kaggle:
#plt.savefig('heatmap.png')

# %%
#plt.savefig('heatmap.png')
